# %%
from sage.misc.prandom import randrange
from sage.misc.randstate import current_randstate
(x,y)=100*random(),100*random()
x,y
# Out:
# (5.692945553088813, 93.1727428633184)

# %%
x1=0
y1=0
x2=100
y2=100
a1=((x1+x2)/2,y1)
a2=(x2,(y1+y2)/2)
a3=((x2+x1)/2,y2)
a4=(x1,(y2+y1)/2)
a5=((x1+x2)/2,(y1+y2)/2)
a5
p=line([a1,a3])+line([a2,a4])+point([x,y],color='red',pointsize=10)+line([(0,0),(100,0)])+line([(100,0),(100,100)])+line([(0,100),(100,100)])+line([(0,0),(0,100)])
p.show()
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
print(x,y)
for i in range(6):
    if(x>a5[0]):
        x1=a5[0]
        if(y>a5[1]):
            y1=a5[1]
        else:
            y2=a5[1]
    else:
        x2=a5[0]
        if(y>a5[1]):
            y1=a5[1]
        else:
            y2=a5[1]
    a1=((x1+x2)/2,y1)
    a2=(x2,(y1+y2)/2)
    a3=((x2+x1)/2,y2)
    a4=(x1,(y2+y1)/2)
    p=p+line([a1,a3])+line([a2,a4])+point([a5],color='green',pointsize=10)
    a5=((x1+x2)/2,(y1+y2)/2)
print(x1,x2,y1,y2)
# Out:
# (5.692945553088813, 93.1727428633184)
# (75/16, 25/4, 1475/16, 375/4)

# %%
p.show()
# Out:
# Graphics object consisting of 25 graphics primitives
